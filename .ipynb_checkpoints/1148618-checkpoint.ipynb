# %% [markdown]
# # Assignment 1: Preprocessing and Text Classification

# %% [markdown]
# Student Name: Sharodh Keelamanakudi Ragupathi
#
# Student ID: 1148618

# %% [markdown]
# # General Info
#
# <b>Due date</b>: Sunday, 28 March 2021 5pm
#
# <b>Submission method</b>: Canvas submission
#
# <b>Submission materials</b>: completed copy of this iPython notebook
#
# <b>Late submissions</b>: -10% per day (both week and weekend days counted)
#
# <b>Marks</b>: 9% of mark for class (with 8% on correctness + 1% on quality and efficiency of your code)
#
# <b>Materials</b>: See [Using Jupyter Notebook and Python page](https://canvas.lms.unimelb.edu.au/courses/121115/pages/using-jupyter-notebook-and-python?module_item_id=2681264) on Canvas (under Modules>Resources) for information on the basic setup required for this class, including an iPython notebook viewer and the python packages NLTK, Numpy, Scipy, Matplotlib, Scikit-Learn, and Gensim. We recommend installing all the data for NLTK, since you will need various parts of it to complete this assignment. You can also use any Python built-in packages, but do not use any other 3rd party packages (the packages listed above are all fine to use); if your iPython notebook doesn't run on the marker's machine, you will lose marks. <b> You should use Python 3</b>.
#
# To familiarize yourself with NLTK, here is a free online book:  Steven Bird, Ewan Klein, and Edward Loper (2009). <a href=http://nltk.org/book>Natural Language Processing with Python</a>. O'Reilly Media Inc. You may also consult the <a href=https://www.nltk.org/api/nltk.html>NLTK API</a>.
#
# <b>Evaluation</b>: Your iPython notebook should run end-to-end without any errors in a reasonable amount of time, and you must follow all instructions provided below, including specific implementation requirements and instructions for what needs to be printed (please avoid printing output we don't ask for). You should edit the sections below where requested, but leave the rest of the code as is. You should leave the output from running your code in the iPython notebook you submit, to assist with marking. The amount each question is worth is explicitly given.
#
# You will be marked not only on the correctness of your methods, but also the quality and efficency of your code: in particular, you should be careful to use Python built-in functions and operators when appropriate and pick descriptive variable names that adhere to <a href="https://www.python.org/dev/peps/pep-0008/">Python style requirements</a>. If you think it might be unclear what you are doing, you should comment your code to help the marker make sense of it.
#
# <b>Updates</b>: Any major changes to the assignment will be announced via Canvas. Minor changes and clarifications will be announced on the discussion board; we recommend you check it regularly.
#
# <b>Academic misconduct</b>: For most people, collaboration will form a natural part of the undertaking of this homework, and we encourge you to discuss it in general terms with other students. However, this ultimately is still an individual task, and so reuse of code or other instances of clear influence will be considered cheating. We will be checking submissions for originality and will invoke the University’s <a href="http://academichonesty.unimelb.edu.au/policy.html">Academic Misconduct policy</a> where inappropriate levels of collusion or plagiarism are deemed to have taken place.

# %% [markdown]
# # Overview
#
# In this homework, you'll be working with a collection tweets. The task is to predict the geolocation (country) where the tweet comes from. This homework involves writing code to preprocess data and perform text classification.

# %% [markdown]
# # Preprocessing (4 marks)

# %% [markdown]
# **Instructions**: Download the data (as1-data.json) from Canvas and put it in the same directory as this iPython notebook. Run the code below to load the json data. This produces two objects, `x` and `y`, which contains a list of  tweets and corresponding country labels (it uses the standard [2 letter country code](https://www.iban.com/country-codes)) respectively. **No implementation is needed.**

# %%
import json

x = []
y = []
data = json.load(open("as1-data.json"))
for k, v in data.items():
    x.append(k)
    y.append(v)
    
print("Number of tweets =", len(x))
print("Number of labels =", len(y))
print("\nSamples of data:")
for i in range(10):
    print("Country =", y[i], "\tTweet =", x[i])
    
assert(len(x) == 943)
assert(len(y) == 943)
# Out:
# Number of tweets = 943
# Number of labels = 943
#
# Samples of data:
# Country = us 	Tweet = @Addictd2Success thx u for following
# Country = us 	Tweet = Let's just say, if I were to ever switch teams, Khalesi would be top of the list. #girlcrush
# Country = ph 	Tweet = Taemin jonghyun!!! Your birits make me go~ http://t.co/le8z3dntlA
# Country = id 	Tweet = depart.senior 👻 rapat perdana (with Nyayu, Anita, and 8 others at Ruang Aescullap FK Unsri Madang) — https://t.co/swRALlNkrQ
# Country = ph 	Tweet = Done with internship with this pretty little lady!  (@ Metropolitan Medical Center w/ 3 others) [pic]: http://t.co/1qH61R1t5r
# Country = gb 	Tweet = Wow just Boruc's clanger! Haha Sunday League stuff that, Giroud couldn't believe his luck! #clown
# Country = my 	Tweet = I'm at Sushi Zanmai (Petaling Jaya, Selangor) w/ 5 others http://t.co/bcNobykZ
# Country = us 	Tweet = Mega Fest!!!! Its going down🙏🙌  @BishopJakes
# Country = gb 	Tweet = @EllexxxPharrell wow love the pic babe xx
# Country = us 	Tweet = You have no clue how much you hurt me

# %% [markdown]
# ### Question 1 (1.0 mark)
#
# **Instructions**: Next we need to preprocess the collected tweets to create a bag-of-words representation. The preprocessing steps required here are: (1) tokenize each tweet into individual word tokens (using NLTK `TweetTokenizer`); (2) lowercase all words; (3) remove any word that does not contain any English alphabets (e.g. {_hello_, _#okay_, _abc123_} would be kept, but not {_123_, _!!_}) and (4) remove stopwords (based on NLTK `stopwords`). An empty tweet (after preprocessing) and its country label should be **excluded** from the output (`x_processed` and `y_processed`).
#
# **Task**: Complete the `preprocess_data(data, labels)` function. The function takes **a list of tweets** and **a corresponding list of country labels** as input, and returns **two lists**. For the first list, each element is a bag-of-words representation of a tweet. For the second list, each element is a corresponding country label. Note that while we do not need to preprocess the country labels (`y`), we need to have a new output list (`y_processed`) because some tweets maybe removed after the preprocessing (due to having an empty set of bag-of-words).
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import re, collections

tt = TweetTokenizer()
stopwords = set(stopwords.words('english')) #note: stopwords are all in lowercase

def preprocess_data(data, labels):
    
    ###
    # Your answer BEGINS HERE
    ###
    data_processed = []
    labels_processed = []
    for i in range(len(data)):
        bagOfWords = collections.defaultdict(int)
        for word in tt.tokenize(data[i]):
            wordProcessed = word.lower()
            if re.search('[a-zA-Z]', wordProcessed) and (wordProcessed not in stopwords):
                bagOfWords[wordProcessed] += 1
                
        if len(bagOfWords) > 0:
            data_processed.append(bagOfWords)
            labels_processed.append(labels[i])
            
    return data_processed, labels_processed
    ###
    # Your answer ENDS HERE
    ###

x_processed, y_processed = preprocess_data(x, y)

print("Number of preprocessed tweets =", len(x_processed))
print("Number of preprocessed labels =", len(y_processed))
print("\nSamples of preprocessed data:")
for i in range(10):
    print("Country =", y_processed[i], "\tTweet =", x_processed[i])
# Out:
# Number of preprocessed tweets = 943
# Number of preprocessed labels = 943
#
# Samples of preprocessed data:
# Country = us 	Tweet = defaultdict(<class 'int'>, {'@addictd2success': 1, 'thx': 1, 'u': 1, 'following': 1})
# Country = us 	Tweet = defaultdict(<class 'int'>, {"let's": 1, 'say': 1, 'ever': 1, 'switch': 1, 'teams': 1, 'khalesi': 1, 'would': 1, 'top': 1, 'list': 1, '#girlcrush': 1})
# Country = ph 	Tweet = defaultdict(<class 'int'>, {'taemin': 1, 'jonghyun': 1, 'birits': 1, 'make': 1, 'go': 1, 'http://t.co/le8z3dntla': 1})
# Country = id 	Tweet = defaultdict(<class 'int'>, {'depart.senior': 1, 'rapat': 1, 'perdana': 1, 'nyayu': 1, 'anita': 1, 'others': 1, 'ruang': 1, 'aescullap': 1, 'fk': 1, 'unsri': 1, 'madang': 1, 'https://t.co/swrallnkrq': 1})
# Country = ph 	Tweet = defaultdict(<class 'int'>, {'done': 1, 'internship': 1, 'pretty': 1, 'little': 1, 'lady': 1, 'metropolitan': 1, 'medical': 1, 'center': 1, 'w': 1, 'others': 1, 'pic': 1, 'http://t.co/1qh61r1t5r': 1})
# Country = gb 	Tweet = defaultdict(<class 'int'>, {'wow': 1, "boruc's": 1, 'clanger': 1, 'haha': 1, 'sunday': 1, 'league': 1, 'stuff': 1, 'giroud': 1, 'believe': 1, 'luck': 1, '#clown': 1})
# Country = my 	Tweet = defaultdict(<class 'int'>, {"i'm": 1, 'sushi': 1, 'zanmai': 1, 'petaling': 1, 'jaya': 1, 'selangor': 1, 'w': 1, 'others': 1, 'http://t.co/bcnobykz': 1})
# Country = us 	Tweet = defaultdict(<class 'int'>, {'mega': 1, 'fest': 1, 'going': 1, '@bishopjakes': 1})
# Country = gb 	Tweet = defaultdict(<class 'int'>, {'@ellexxxpharrell': 1, 'wow': 1, 'love': 1, 'pic': 1, 'babe': 1, 'xx': 1})
# Country = us 	Tweet = defaultdict(<class 'int'>, {'clue': 1, 'much': 1, 'hurt': 1})

# %% [markdown]
# **For your testing**:

# %%
assert(len(x_processed) == len(y_processed))
assert(len(x_processed) > 800)

# %% [markdown]
# **Instructions**: Hashtags (i.e. topic tags which start with #) pose an interesting tokenisation problem because they often include multiple words written without spaces or capitalization. Run the code below to collect all unique hashtags in the preprocessed data. **No implementation is needed.**

# %%
def get_all_hashtags(data):
    hashtags = set([])
    for d in data:
        for word, frequency in d.items():
            if word.startswith("#") and len(word) > 1:
                hashtags.add(word)
    return hashtags

hashtags = get_all_hashtags(x_processed)
print("Number of hashtags =", len(hashtags))
print(sorted(hashtags))
# Out:
# Number of hashtags = 425
# ['#100percentpay', '#1stsundayofoctober', '#1yearofalmostisneverenough', '#2011prdctn', '#2015eebritishfilmacademyawards', '#2k16', '#2littlebirds', '#365picture', '#5sosacousticatlanta', '#5sosfam', '#8thannualpubcrawl', '#affsuzukicup', '#aflpowertigers', '#ahimacon14', '#aim20', '#airasia', '#allcity', '#alliswell', '#allwedoiscurls', '#amazing', '#anferneehardaway', '#ariona', '#art', '#arte', '#artwork', '#ashes', '#asian', '#asiangirl', '#askcrawford', '#askherforfback', '#askolly', '#asksteven', '#at', '#australia', '#awesome', '#awesomepict', '#barcelona', '#bart', '#bayofislands', '#beautiful', '#bedimages', '#bell', '#beringmy', '#bettybooppose', '#bff', '#big', '#bigbertha', '#bigbreakfast', '#blackhat', '#blessedmorethanicanimagine', '#blessedsunday', '#blogtourambiente', '#bluemountains', '#bonekachika', '#boomtaob', '#booyaa', '#bored', '#boredom', '#bradersisterhood', '#breaktime', '#breedingground', '#bringithomemy', '#brooksengland', '#burgers', '#butitsalsokindofaphone', '#bye', '#camera', '#canadaelections', '#cbb', '#cbcolympics', '#cctv', '#cdnpoli', '#celebritycrush', '#chargers', '#chocolate', '#ciosummit', '#cleansidewalk', '#clown', '#coffeespoonart', '#colts', '#confused', '#cornell', '#country', '#craftbeer', '#creative', '#crepes', '#cumannanya', '#danny4mayor', '#data', '#date', '#datingsiteforyou', '#dearmind', '#deed', '#delightful', '#dennisrodman', '#design', '#devacurl', '#die', '#difd', '#diner', '#dinner', '#dragoncon', '#dus', '#dynamounlock', '#earrings', '#eeeeeehhh', '#election2015', '#electriccircus2014', '#endomondo', '#engine', '#english', '#europapark', '#excitables', '#fabulous', '#factorycampus', '#fall', '#familydinner', '#ff', '#fire', '#flambees', '#flashback', '#fly', '#focusateneo', '#followher', '#followme', '#foodporn', '#fotografías', '#fotorus', '#four', '#freaks', '#friday', '#fridaynight', '#fried', '#friends', '#friendshipflow', '#fries', '#frozenyoghurt', '#fun', '#future', '#galaxy', '#getfreetattooaviciipasses', '#girl', '#girlcrush', '#girls', '#givesmehope', '#goingout', '#google', '#graduated', '#grafunkthiremepls', '#grammyfans', '#grandmarnier', '#greenfood', '#grilled', '#gudnytall', '#gunner', '#gym', '#handbuiltbicycle', '#happybirthdaysandarapark', '#happyfriday', '#harimaumalaya', '#hb60', '#hens', '#hippy', '#holiday', '#hollywoodmusicawards', '#homemadegranola', '#hometomama', '#hot', '#hungergames', '#hungry', '#icu', '#ididntchoosethestudentlifeitchoseme', '#iloveyou', '#imsobored', '#imsosore', '#innoretail', '#insanity', '#insightmedia', '#insightmediasingapore', '#instaframeplus', '#instagood', '#instalook', '#isibaya', '#javaboy', '#jed', '#jewelry', '#jo', '#jordaan', '#jrsurfboards', '#justshare', '#kllive', '#ladygaga', '#latepost', '#laugh', '#laundryservice', '#lazysunday', '#learningcommunties', '#lebedeintennis', '#letmesleep', '#lfc', '#lgbt', '#life', '#lipstickfree', '#littlemonsters', '#loadsoffun', '#lol', '#longranger', '#lotsoflove', '#love', '#lovers', '#lovethisgirl', '#lovevibes', '#lte', '#magazinesandtvscreens', '#magic', '#makeupfree', '#makingemuklajawabnya', '#mamajeanneandme', '#mancrush', '#march', '#massacreconspiracy', '#mauce', '#mavic', '#me', '#meetup', '#melbourne', '#michaelkors', '#mindfulness', '#mkmedi', '#mobile', '#morning', '#mountains', '#movies', '#mtlnewtech', '#mtvhottest', '#mushroom', '#music', '#mustfollow', '#mwc14', '#mybabyemilia', '#myfriendsarebetterthanyours', '#nced', '#ncga', '#ncpol', '#nevergetsold', '#new', '#newlooks', '#newrecord', '#nextlevel', '#nfl', '#nickryrie', '#nochillzone', '#nofilter', '#notersnew2014', '#notreally', '#np', '#nye', '#of', '#offtochurch', '#ohyeah', '#oilandgas', '#olah', '#on', '#oops', '#openspace', '#oscars', '#oui', '#palacefansinthemorning', '#panther', '#panthers', '#partyhardpartyy', '#pats', '#pechanga', '#penny', '#peperoni', '#peppermoney', '#photo', '#photoby', '#photography', '#pic', '#pll', '#pmattheashes', '#pop-up', '#positivity', '#potd', '#procrastina ...

# %% [markdown]
# ### Question 2 (1.0 mark)
#
# **Instructions**: Our task here to tokenize the hashtags, by implementing the **MaxMatch algorithm** discussed in class.
#
# NLTK has a list of words that you can use for matching, see starter code below (`words`). Be careful about efficiency with respect to doing word lookups. One extra challenge you have to deal with is that the provided list of words (`words`) includes only lemmas: your MaxMatch algorithm should match inflected forms by converting them into lemmas using the NLTK lemmatizer before matching (provided by the function `lemmatize(word)`). Note that the list of words (`words`) is the only source that you'll use for matching (i.e. you do not need to find  other external word lists). If you are unable to make any longer match, your code should default to matching a single letter.
#
# For example, given "#newrecord", the algorithm should produce: \["#", "new", "record"\].
#
# **Task**: Complete the `tokenize_hashtags(hashtags)` function by implementing the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
import nltk
from nltk.corpus import wordnet

lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
words = set(nltk.corpus.words.words()) #a list of words provided by NLTK
words = set([ word.lower() for word in words ]) #lowercase all the words for better matching

def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma


def tokenize_hashtags(hashtags):
    ###
    # Your answer BEGINS HERE
    ###    
    tokenizedWords = collections.defaultdict(list)
    
    for tag in hashtags:
    
        leftPointer = 0
        rightPointer = len(tag)
        
        while leftPointer < rightPointer:
            token = tag[leftPointer:rightPointer]
            tokenLemma = lemmatize(token)
            if tokenLemma in words or rightPointer-1 == leftPointer:
                tokenizedWords[tag].append(token)
                leftPointer += len(token)
                rightPointer = len(tag)
            else:
                rightPointer -= 1
                
    return tokenizedWords
    ###
    # Your answer ENDS HERE
    ###

#tokenise hashtags with MaxMatch
tokenized_hashtags = tokenize_hashtags(hashtags)

#print results
for k, v in sorted(tokenized_hashtags.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'vega', 'n']
# #veganfood ['#', 'vega', 'n', 'food']
# #vegetables ['#', 'vegetables']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'vs', 'c', 'o']
# #vscocam ['#', 'vs', 'coca', 'm']
# #walking ['#', 'walking']
# #watch ['#', 'watch']
# #weare90s ['#', 'wear', 'e', '9', '0', 's']
# #wearesocial ['#', 'weares', 'o', 'c', 'i', 'al']
# #white ['#', 'white']
# #wings ['#', 'wings']
# #wok ['#', 'wo', 'k']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mates']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'ama', 's']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'ws', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags) == len(hashtags))
assert(tokenized_hashtags["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 3 (1.0 mark)
#
# **Instructions**: Our next task is to tokenize the hashtags again, but this time using a **reversed version of the MaxMatch algorithm**, where matching begins at the end of the hashtag and progresses backwards (e.g. for <i>#helloworld</i>, we would process it right to left, starting from the last character <i>d</i>). Just like before, you should use the provided word list (`words`) for word matching.
#
# **Task**: Complete the `tokenize_hashtags_rev(hashtags)` function by the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
def tokenize_hashtags_rev(hashtags):
    ###
    # Your answer BEGINS HERE
    ###
    
    tokenizedWords = collections.defaultdict(list)
    
    for tag in hashtags:
    
        leftPointer = 0
        rightPointer = len(tag)
        
        while leftPointer < rightPointer:
            token = tag[leftPointer:rightPointer]
            tokenLemma = lemmatize(token)
            if tokenLemma in words or rightPointer-1 == leftPointer:
                tokenizedWords[tag].insert(0,token)
                leftPointer = 0
                rightPointer -= len(token)
            else:
                leftPointer += 1
                
    return tokenizedWords
    ###
    # Your answer ENDS HERE
    ###

    
#tokenise hashtags with the reversed version of MaxMatch
tokenized_hashtags_rev = tokenize_hashtags_rev(hashtags)

#print results
for k, v in sorted(tokenized_hashtags_rev.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'v', 'e', 'gan']
# #veganfood ['#', 'v', 'e', 'gan', 'food']
# #vegetables ['#', 'vegetables']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'vs', 'c', 'o']
# #vscocam ['#', 'vs', 'c', 'o', 'cam']
# #walking ['#', 'walking']
# #watch ['#', 'watch']
# #weare90s ['#', 'we', 'are', '9', '0', 's']
# #wearesocial ['#', 'we', 'are', 'social']
# #white ['#', 'white']
# #wings ['#', 'wings']
# #wok ['#', 'w', 'ok']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mates']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'a', 'mas']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'ws', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags_rev) == len(hashtags))
assert(tokenized_hashtags_rev["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 4 (1.0 mark)
#
# **Instructions**: The two versions of MaxMatch will produce different results for some of the hashtags. For a hastag that has different results, our task here is to use a **unigram language model** (lecture 3) to score them to see which is better. Recall that in a unigram language model we compute P(<i>#</i>, <i>hello</i>, <i>world</i> = P(<i>#</i>)\*P(<i>hellow</i>)\*P(<i>world</i>).
#
# You should: (1) use the NLTK's Brown corpus (`brown_words`) for collecting word frequencies (note: the words are already tokenised so no further tokenisation is needed); (2) lowercase all words in the corpus; (3) use add-one smoothing when computing the unigram probabilities; and (4) work in the log space to prevent numerical underflow.
#
# **Task**: Build a unigram language model with add-one smoothing using the word counts from the Brown corpus. Iterate through the hashtags, and for each hashtag where MaxMatch and reversed MaxMatch produce different results, print the following: (1) the hashtag; (2) the results produced by MaxMatch and reversed MaxMatch; and (3) the log probability of each result as given by the unigram language model. Note: you **do not** need to print the hashtags where MaxMatch and reversed MaxMatch produce the same results.
#
# An example output:
# ```
# 1. #abcd
# MaxMatch = [#, a, bc, d]; LogProb = -2.3
# Reversed MaxMatch = [#, a, b, cd]; LogProb = -3.5
#
# 2. #efgh
# MaxMatch = [#, ef, g, h]; LogProb = -4.2
# Reversed MaxMatch = [#, e, fgh]; LogProb = -3.1
#
# ```
#
# Have a look at the output, and see if the sequences with better language model scores (i.e. less negative) are generally more coherent.

# %%
from nltk.corpus import brown
import math

#words from brown corpus
brown_words = brown.words()
brown_words = [word.lower() for word in brown_words] #lowercase all the words for better matching

brown_words_len = len(brown_words)
brown_words_types = len(set(brown_words))

###
# Your answer BEGINS HERE
###
counter = 1

for tag in tokenized_hashtags_rev.keys():
    
    if (sorted(tokenized_hashtags[tag], key=len) != sorted(tokenized_hashtags_rev[tag], key=len)):
        prob_tokenized_hashtag = 0
        for token in tokenized_hashtags[tag]:
            prob_tokenized_hashtag += math.log((brown_words.count(token) + 1)/(brown_words_len + brown_words_types))
            
        prob_tokenized_hashtag_rev = 0
        for token in tokenized_hashtags_rev[tag]:
            prob_tokenized_hashtag_rev += math.log((brown_words.count(token) + 1)/(brown_words_len + brown_words_types))
            
        print("==========")
        print (f"{counter}. {tag}")
        print (f"MaxMatch = {tokenized_hashtags[tag]}; LogProb = {prob_tokenized_hashtag}")
        print (f"Reversed MaxMatch = {tokenized_hashtags_rev[tag]}; LogProb = {prob_tokenized_hashtag_rev}")
        
        counter += 1
            
###
# Your answer ENDS HERE
###
# Out:
# ==========
# 1. #melbourne
# MaxMatch = ['#', 'mel', 'bourn', 'e']; LogProb = -49.423907386860904
# Reversed MaxMatch = ['#', 'm', 'elb', 'our', 'ne']; LogProb = -58.12239456631912
# ==========
# 2. #blessedmorethanicanimagine
# MaxMatch = ['#', 'blessed', 'more', 'than', 'i', 'can', 'imagine']; LogProb = -60.058470767841214
# Reversed MaxMatch = ['#', 'blessed', 'more', 'th', 'ani', 'can', 'imagine']; LogProb = -75.00004826278757
# ==========
# 3. #excitables
# MaxMatch = ['#', 'excitable', 's']; LogProb = -38.88539419266688
# Reversed MaxMatch = ['#', 'ex', 'c', 'i', 'tables']; LogProb = -51.77585780960129
# ==========
# 4. #cbcolympics
# MaxMatch = ['#', 'c', 'b', 'coly', 'm', 'pics']; LogProb = -71.74110333429053
# Reversed MaxMatch = ['#', 'c', 'b', 'col', 'ym', 'pics']; LogProb = -74.57431667834675
# ==========
# 5. #uniexamonasaturday
# MaxMatch = ['#', 'unie', 'x', 'am', 'ona', 'saturday']; LogProb = -71.5774097161047
# Reversed MaxMatch = ['#', 'u', 'ni', 'ex', 'a', 'mona', 'saturday']; LogProb = -80.03982716760159
# ==========
# 6. #cumannanya
# MaxMatch = ['#', 'cum', 'anna', 'n', 'ya']; LogProb = -62.68237291408313
# Reversed MaxMatch = ['#', 'c', 'u', 'mannan', 'ya']; LogProb = -60.9822977275441
# ==========
# 7. #myfriendsarebetterthanyours
# MaxMatch = ['#', 'my', 'friends', 'are', 'better', 'than', 'yours']; LogProb = -60.60523299610116
# Reversed MaxMatch = ['#', 'my', 'friend', 'sare', 'better', 'than', 'yours']; LogProb = -69.18936620707629
# ==========
# 8. #mtlnewtech
# MaxMatch = ['#', 'm', 't', 'l', 'newt', 'e', 'c', 'h']; LogProb = -88.13969538899899
# Reversed MaxMatch = ['#', 'm', 't', 'l', 'new', 'tech']; LogProb = -64.42140720789112
# ==========
# 9. #ciosummit
# MaxMatch = ['#', 'c', 'ios', 'um', 'mi', 't']; LogProb = -71.88531467221522
# Reversed MaxMatch = ['#', 'c', 'io', 'summit']; LogProb = -47.96573362870664
# ==========
# 10. #lebedeintennis
# MaxMatch = ['#', 'l', 'e', 'bed', 'e', 'in', 'tennis']; LogProb = -70.19551835668177
# Reversed MaxMatch = ['#', 'l', 'e', 'be', 'de', 'in', 'tennis']; LogProb = -65.18832648436327
# ==========
# 11. #ariona
# MaxMatch = ['#', 'arion', 'a']; LogProb = -31.969153279599702
# Reversed MaxMatch = ['#', 'ar', 'i', 'ona']; LogProb = -47.47819082990764
# ==========
# 12. #blogtourambiente
# MaxMatch = ['#', 'blo', 'g', 'tour', 'ambient', 'e']; LogProb = -73.71080177251329
# Reversed MaxMatch = ['#', 'b', 'log', 'tou', 'ram', 'bien', 'te']; LogProb = -89.10863440692928
# ==========
# 13. #mamajeanneandme
# MaxMatch = ['#', 'mam', 'a', 'jeanne', 'and', 'me']; LogProb = -56.645074579723975
# Reversed MaxMatch = ['#', 'm', 'ama', 'jeanne', 'and', 'me']; LogProb = -63.17044918410414
# ==========
# 14. #grandmarnier
# MaxMatch = ['#', 'grandma', 'r', 'ni', 'er']; LogProb = -63.73219503858182
# Reversed MaxMatch = ['#', 'grand', 'm', 'arni', 'er']; LogProb = -63.30978037215988
# ==========
# 15. #goingout
# MaxMatch = ['#', 'going', 'out']; LogProb = -28.380684072531803
# Reversed MaxMatch = ['#', 'go', 'in', 'gout']; LogProb = -38.52004758240894
# ==========
# 16. #brooksengland
# MaxMatch = ['#', 'brooks', 'en', 'gland']; LogProb = -48.81261123273127
# Reversed MaxMatch = ['#', 'brook', 'sen', 'gland']; LogProb = -52.33897175734744
# ==========
# 17. #surfshop
# MaxMatch = ['#', 'surfs', 'hop']; LogProb = -40.92227611992792
# Reversed MaxMatch = ['#', 'surf', 'shop']; LogProb = -37.16885814467641
# ==========
# 18. #nickryrie
# MaxMatch = ['#', 'nick', 'r', 'yr', 'ie']; LogProb = -63.1131558301756
# Reversed MaxMatch = ['#', 'nick', 'r', 'y', 'rie']; LogProb = -61.321396360947546
# ==========
# 19. #usydhereicome
# MaxMatch = ['#', 'us', 'y', 'd', 'here', 'i', 'come']; LogProb = -64.19058954620297
# Reversed MaxMatch = ['#', 'u', 'syd', 'here', 'i', 'come']; LogProb = -59.78434759171772
# ==========
# 20. #openspace
# MaxMatch = ['#', 'opens', 'pace']; LogProb = -35.40348543062156
# Reversed MaxMatch = ['#', 'open', 'space']; LogProb = -31.03534148073286
# ==========
# 21. #seniorbabysenior
# MaxMatch = ['#', 'senior', 'babys', 'en', 'io', 'r']; LogProb = -74.05027838733322
# Reversed MaxMatch = ['#', 'senior', 'baby', 'senior']; LogProb = -44.77402036209102
# ==========
# 22. #learningcommunties
# MaxMatch = ['#', 'learning', 'c', 'om', 'munt', 'ies']; LogProb = -75.1268819082855
# Reversed MaxMatch = ['#', 'learning', 'c', 'om', 'm', 'unties']; LogProb = -72.29366856422928
# ==========
# 23. #shopaholic
# MaxMatch = ['#', 'shop', 'aho', 'li', 'c']; LogProb = -61.0719098862338
# Reversed MaxMatch = ['#', 'sho', 'paho', 'li', 'c']; LogProb = -65.23079296959347
# ==========
# 24. #asksteven
# MaxMatch = ['#', 'asks', 'te', 'v', 'en']; LogProb = -61.678728983305234
# Reversed MaxMatch = ['#', 'ask', 'steven']; LogProb = -37.16107600423436
# ==========
# 25. #bedimages
# MaxMatch = ['#', 'bedim', 'ages']; LogProb = -38.069644690014606
# Reversed MaxMatch = ['#', 'bed', 'images']; LogProb = -33.53127198495003
# ==========
# 26. #takeabreak
# MaxMatch = ['#', 'take', 'ab', 'reak']; LogProb = -48.22645989116989
# Reversed MaxMatch = ['#', 'ta', 'kea', 'break']; LogProb = -51.53921484172923
# ==========
# 27. #focusateneo
# MaxMatch = ['#', 'focus', 'aten', 'e', 'o']; LogProb = -59.31183301491378
# Reversed MaxMatch = ['#', 'fo', 'c', 'u', 'sate', 'neo']; LogProb = -76.59869844284354
# ==========
# 28. #getfreetattooaviciipasses
# MaxMatch = ['#', 'get', 'freet', 'at', 'too', 'a', 'vic', 'i', 'i', 'passes']; LogProb = -86.0402830918303
# Reversed MaxMatch = ['#', 'get', 'free', 'tattoo', 'a', 'vic', 'i', 'i', 'passes']; LogProb = -81.7892120735291
# ==========
# 29. #letmesleep
# MaxMatch = ['#', 'let', 'mes', 'leep']; LogProb = -50.07460787717359
# Reversed MaxMatch = ['#', 'let', 'me', 'sleep']; LogProb = -38.80998993718112
# ==========
# 30. #makeupfree
# MaxMatch = ['#', 'make', 'up', 'free']; LogProb = -36.24396639713306
# Reversed MaxMatch = ['#', 'ma', 'keup', 'free']; LogProb = -47.47143730689186
# ==========
# 31. #imsobored
# MaxMatch = ['#', 'i', 'ms', 'o', 'bored']; LogProb = -54.38265427699833
# Reversed MaxMatch = ['#', 'i', 'm', 'so', 'bored']; LogProb = -48.35001224300944
# ==========
# 32. #statoftheday
# MaxMatch = ['#', 'st', 'at', 'oft', 'he', 'day']; LogProb = -59.061507392019756
# Reversed MaxMatch = ['#', 's', 'tat', 'of', 'the', 'day']; LogProb = -52.02081500903782
# ==========
# 33. #pmattheashes
# MaxMatch = ['#', 'p', 'matt', 'he', 'ashes']; LogProb = -53.19461236634763
# Reversed MaxMatch = ['#', 'p', 'mat', 'the', 'ashes']; LogProb = -50.79748853317951
# ==========
# 34. #weare90s
# MaxMatch = ['#', 'wear', 'e', '9', '0', 's']; LogProb = -66.33056265378181
# Reversed MaxMatch = ['#', 'we', 'are', '9', '0', 's']; LogProb = -57.35598449468522
# ==========
# 35. #cleansidewalk
# MaxMatch = ['#', 'cleans', 'ide', 'walk']; LogProb = -50.719583514060176
# Reversed MaxMatch = ['#', 'clean', 'sidewalk']; LogProb = -34.68135071318836
# ==========
# 36. #google
# MaxMatch = ['#', 'goo', 'g', 'l', 'e']; LogProb = -60.65481525950998
# Reversed MaxMatch = ['#', 'go', 'ogle']; LogProb = -35.579941867963115
# ==========
# 37. #ididntchoosethestudentlifeitchoseme
# MaxMatch = ['#', 'id', 'id', 'n', 'tch', 'o', 'ose', 'the', 'student', 'life', 'itch', 'ose', 'me']; LogProb = -143.6520627273642
# Reversed MaxMatch = ['#', 'i', 'didnt', 'choose', 'the', 'student', 'life', 'it', 'cho', 'seme']; LogProb = -95.89774415115184
# ==========
# 38. #peperoni
# MaxMatch = ['#', 'pep', 'er', 'on', 'i']; LogProb = -52.66904173697897
# Reversed MaxMatch = ['#', 'pep', 'e', 'ro', 'ni']; LogProb = -66.32124194762241
# ==========
# 39. #coffeespoonart
# MaxMatch = ['#', 'coffees', 'poon', 'art']; LogProb = -50.68551695949656
# Reversed MaxMatch = ['#', 'coffee', 'spoon', 'art']; LogProb = -44.370158957974226
# ==========
# 40. #allwedoiscurls
# MaxMatch = ['#', 'all', 'wed', 'o', 'is', 'curls']; LogProb = -61.72586615775175
# Reversed MaxMatch = ['#', 'all', 'w', 'edo', 'is', 'curls']; LogProb = -64.32855584319614
# ==========
# 41. #askolly
# MaxMatch = ['#', 'ask', 'o', 'l', 'ly']; LogProb = -59.0459513999045
# Reversed MaxMatch = ['#', 'as', 'kol', 'ly']; LogProb = -47.13854289161853
# ==========
# 42. #butitsalsokindofaphone
# MaxMatch = ['#', 'but', 'its', 'also', 'kind', 'of', 'a', 'phone']; LogProb = -58.856091554731236
# Reversed MaxMatch = ['#', 'bu', 'tits', 'also', 'kin', 'do', 'fa', 'phone']; LogProb = -91.65755389449471
# ==========
# 43. #fotografías
# MaxMatch = ['#', 'fot', 'og', 'ra', 'f', 'í', 'as']; LogProb = -84.85536620701038
# Reversed MaxMatch = ['#', 'f', 'oto', 'gra', 'f', 'í', 'as']; LogProb = -81.93759547492611
# ==========
# 44. #hometomama
# MaxMatch = ['#', 'home', 'toma', 'ma']; LogProb = -46.72584365095937
# Reversed MaxMatch = ['#', 'home', 'tom', 'ama']; LogProb = -44.869545660593744
# ==========
# 45. #skeemsaam
# MaxMatch = ['#', 'skee', 'ms', 'aam']; LogProb = -54.92923892279327
# Reversed MaxMatch = ['#', 's', 'k', 'e', 'ems', 'aam']; LogProb = -74.79481526176023
# ==========
# 46. #bettybooppose
# MaxMatch = ['#', 'betty', 'boo', 'p', 'pose']; LogProb = -61.126660401005196
# Reversed MaxMatch = ['#', 'betty', 'bo', 'oppose']; LogProb = -51.17582094754176
# ==========
# 47. #loadsoffun
# MaxMatch = ['#', 'loads', 'off', 'un']; LogProb = -44.52943043269403
# Reversed MaxMatch = ['#', 'loads', 'of', 'fun']; LogProb = -39.32061231617104
# ==========
# 48. #difd
# MaxMatch = ['#', 'di', 'f', 'd']; LogProb = -45.34961345016367
# Reversed MaxMatch = ['#', 'd', 'if', 'd']; LogProb = -40.46844195545796
# ==========
# 49. #bradersisterhood
# MaxMatch = ['#', 'brad', 'ers', 'ist', 'er', 'hood']; LogProb = -80.57604091439234
# Reversed MaxMatch = ['#', 'brad', 'er', 'sisterhood']; LogProb = -55.334704030901435
# ==========
# 50. #harimaumalaya
# MaxMatch = ['#', 'ha', 'rima', 'um', 'ala', 'ya']; LogProb = -79.72428870365574
# Reversed MaxMatch = ['#', 'h', 'ar', 'i', 'mau', 'mala', 'ya']; LogProb = -84.71158749572162
# ==========
# 51. #blessedsunday
# MaxMatch = ['#', 'blesseds', 'un', 'day']; LogProb = -46.855005043912776
# Reversed MaxMatch = ['#', 'blessed', 'sunday']; LogProb = -34.7568582656965
# ==========
# 52. #fotorus
# MaxMatch = ['#', 'fot', 'or', 'us']; LogProb = -41.16715305182789
# Reversed MaxMatch = ['#', 'fo', 'torus']; LogProb = -42.02088840859603
# ==========
# 53. #thankyoulord
# MaxMatch = ['#', 'thank', 'youl', 'or', 'd']; LogProb = -54.147565385367656
# Reversed MaxMatch = ['#', 'thank', 'you', 'lord']; LogProb = -39.77590794288293
# ==========
# 54. #skullsearcher
# MaxMatch = ['#', 'skulls', 'ear', 'che', 'r']; LogProb = -61.178295517306864
# Reversed MaxMatch = ['#', 'skull', 'searcher']; LogProb = -40.63459404747614
# ==========
# 55. #samsung
# MaxMatch = ['#', 'sams', 'un', 'g']; LogProb = -50.5555805377899
# Reversed MaxMatch = ['#', 'sam', 'sung']; LogProb = -34.69442279475571
# ==========
# 56. #socal
# MaxMatch = ['#', 'soc', 'al']; LogProb = -38.762791870574546
# Reversed MaxMatch = ['#', 'so', 'cal']; LogProb = -33.73386338343097
# ==========
# 57. #bringithomemy
# MaxMatch = ['#', 'bring', 'it', 'home', 'my']; LogProb = -42.3969400397748
# Reversed MaxMatch = ['#', 'brin', 'git', 'home', 'my']; LogProb = -54.934471662227295
# ==========
# 58. #8thannualpubcrawl
# MaxMatch = ['#', '8', 'than', 'nu', 'alp', 'u', 'b', 'crawl']; LogProb = -90.10494111288482
# Reversed MaxMatch = ['#', '8', 'th', 'annual', 'pub', 'crawl']; LogProb = -71.6475993701122
# ==========
# 59. #isibaya
# MaxMatch = ['#', 'is', 'iba', 'ya']; LogProb = -45.19713298701276
# Reversed MaxMatch = ['#', 'i', 'si', 'baya']; LogProb = -46.78504364934769
# ==========
# 60. #1stsundayofoctober
# MaxMatch = ['#', '1', 'st', 'sunday', 'ofo', 'c', 'tobe', 'r']; LogProb = -92.69405063506932
# Reversed MaxMatch = ['#', '1', 'st', 'sunday', 'of', 'october']; LogProb = -58.69378286889845
# ==========
# 61. #anferneehardaway
# MaxMatch = ['#', 'an', 'fern', 'e', 'eh', 'ar', 'daw', 'ay']; LogProb = -97.22465036397413
# Reversed MaxMatch = ['#', 'an', 'f', 'er', 'nee', 'hard', 'away']; LogProb = -74.77282410312905
# ==========
# 62. #magazinesandtvscreens
# MaxMatch = ['#', 'magazines', 'and', 't', 'vs', 'creen', 's']; LogProb = -75.41899821647736
# Reversed MaxMatch = ['#', 'magazine', 'sand', 't', 'v', 'screens']; LogProb = -66.89879292342849
# ==========
# 63. #instagood
# MaxMatch = ['#', 'ins', 'tag', 'o', 'od']; LogProb = -64.94721767909434
# Reversed MaxMatch = ['#', 'ins', 'ta', 'good']; LogProb = -49.33452754319143
# ==========
# 64. #meetup
# MaxMatch = ['#', 'meet', 'up']; LogProb = -29.465392045841316
# Reversed MaxMatch = ['#', 'me', 'e', 'tup']; LogProb = -45.239315946791024
# ==========
# 65. #pechanga
# MaxMatch = ['#', 'pech', 'an', 'ga']; LogProb = -47.107595796553284
# Reversed MaxMatch = ['#', 'p', 'e', 'changa']; LogProb = -47.970473722903385
# ==========
# 66. #rainorshine
# MaxMatch = ['#', 'rain', 'ors', 'hin', 'e']; LogProb = -62.0585620705811
# Reversed MaxMatch = ['#', 'r', 'ai', 'nor', 'shine']; LogProb = -58.60823105917856
# ==========
# 67. #veganfood
# MaxMatch = ['#', 'vega', 'n', 'food']; LogProb = -47.36707729156761
# Reversed MaxMatch = ['#', 'v', 'e', 'gan', 'food']; LogProb = -57.99182516368309
# ==========
# 68. #startuphub
# MaxMatch = ['#', 'start', 'up', 'hub']; LogProb = -40.954658376095665
# Reversed MaxMatch = ['#', 'star', 'tup', 'hub']; LogProb = -50.2848480236519
# ==========
# 69. #booyaa
# MaxMatch = ['#', 'boo', 'ya', 'a']; LogProb = -43.673530989471
# Reversed MaxMatch = ['#', 'boo', 'y', 'aa']; LogProb = -52.84979738111343
# ==========
# 70. #happybirthdaysandarapark
# MaxMatch = ['#', 'happy', 'birthdays', 'anda', 'rap', 'ark']; LogProb = -78.34804467838937
# Reversed MaxMatch = ['#', 'happy', 'birthday', 'sand', 'ara', 'park']; LogProb = -68.58104526630402
# ==========
# 71. #grammyfans
# MaxMatch = ['#', 'gram', 'my', 'fans']; LogProb = -43.354284332587376
# Reversed MaxMatch = ['#', 'g', 'rammy', 'fans']; LogProb = -50.10359541404684
# ==========
# 72. #alliswell
# MaxMatch = ['#', 'all', 'is', 'well']; LogProb = -31.999366818951252
# Reversed MaxMatch = ['#', 'al', 'li', 'swell']; LogProb = -50.690313131760064
# ==========
# 73. #datingsiteforyou
# MaxMatch = ['#', 'datings', 'it', 'e', 'for', 'you']; LogProb = -53.9944149525532
# Reversed MaxMatch = ['#', 'dating', 'site', 'for', 'you']; LogProb = -46.99526436672879
# ==========
# 74. #beringmy
# MaxMatch = ['#', 'beri', 'n', 'g', 'my']; LogProb = -56.353409871423544
# Reversed MaxMatch = ['#', 'be', 'ring', 'my']; LogProb = -36.21141120026617
# ==========
# 75. #yiamas
# MaxMatch = ['#', 'y', 'i', 'ama', 's']; LogProb = -55.86475276705583
# Reversed MaxMatch = ['#', 'y', 'i', 'a', 'mas']; LogProb = -49.641659034548596
# ==========
# 76. #singapore
# MaxMatch = ['#', 'sing', 'a', 'pore']; LogProb = -41.32215573230752
# Reversed MaxMatch = ['#', 's', 'inga', 'pore']; LogProb = -51.79374470686412
# ==========
# 77. #oilandgas
# MaxMatch = ['#', 'oil', 'and', 'gas']; LogProb = -36.58832892349973
# Reversed MaxMatch = ['#', 'o', 'i', 'land', 'gas']; LogProb = -48.19507485096406
# ==========
# 78. #toronto
# MaxMatch = ['#', 'toro', 'n', 'to']; LogProb = -42.19234098679093
# Reversed MaxMatch = ['#', 'tor', 'onto']; LogProb = -37.91001454442272
# ==========
# 79. #ladygaga
# MaxMatch = ['#', 'lady', 'gag', 'a']; LogProb = -39.9722290153585
# Reversed MaxMatch = ['#', 'lady', 'g', 'aga']; LogProb = -48.80018871273272
# ==========
# 80. #thankyoupatients
# MaxMatch = ['#', 'thank', 'youp', 'ati', 'en', 'ts']; LogProb = -78.351417362868
# Reversed MaxMatch = ['#', 'thank', 'you', 'patients']; LogProb = -40.70828481250871
# ==========
# 81. #vegan
# MaxMatch = ['#', 'vega', 'n']; LogProb = -38.357326762466386
# Reversed MaxMatch = ['#', 'v', 'e', 'gan']; LogProb = -48.98207463458186
# ==========
# 82. #olah
# MaxMatch = ['#', 'o', 'la', 'h']; LogProb = -45.58366860155698
# Reversed MaxMatch = ['#', 'o', 'l', 'ah']; LogProb = -46.763306785471684
# ==========
# 83. #startupfest
# MaxMatch = ['#', 'start', 'up', 'fest']; LogProb = -43.43956502588367
# Reversed MaxMatch = ['#', 'star', 'tup', 'fest']; LogProb = -52.7697546734399
# ==========
# 84. #askherforfback
# MaxMatch = ['#', 'ask', 'her', 'for', 'f', 'back']; LogProb = -51.52022864808315
# Reversed MaxMatch = ['#', 'ask', 'her', 'f', 'orf', 'back']; LogProb = -60.67822253968713
# ==========
# 85. #flambees
# MaxMatch = ['#', 'flamb', 'e', 'es']; LogProb = -52.314279144757066
# Reversed MaxMatch = ['#', 'flam', 'bees']; LogProb = -39.24829968635625
# ==========
# 86. #ahimacon14
# MaxMatch = ['#', 'ah', 'ima', 'con', '1', '4']; LogProb = -67.22502598261144
# Reversed MaxMatch = ['#', 'a', 'hi', 'macon', '1', '4']; LogProb = -58.83287854973469
# ==========
# 87. #arte
# MaxMatch = ['#', 'art', 'e']; LogProb = -32.96498208992691
# Reversed MaxMatch = ['#', 'ar', 'te']; LogProb = -42.02088840859603
# ==========
# 88. #reachingyougpeople
# MaxMatch = ['#', 'reaching', 'you', 'g', 'people']; LogProb = -48.576799826896114
# Reversed MaxMatch = ['#', 'reaching', 'yo', 'ug', 'people']; LogProb = -59.507743744616555
# ==========
# 89. #instalook
# MaxMatch = ['#', 'ins', 'tal', 'o', 'ok']; LogProb = -64.94721767909434
# Reversed MaxMatch = ['#', 'ins', 'ta', 'look']; LogProb = -50.03638666435339
# ==========
# 90. #swedumtl
# MaxMatch = ['#', 's', 'wed', 'um', 't', 'l']; LogProb = -71.0083102294149
# Reversed MaxMatch = ['#', 's', 'we', 'dum', 't', 'l']; LogProb = -65.83291407637937
# ==========
# 91. #palacefansinthemorning
# MaxMatch = ['#', 'palace', 'fans', 'in', 'them', 'or', 'ning']; LogProb = -65.4919735537188
# Reversed MaxMatch = ['#', 'palace', 'fan', 'sin', 'the', 'morning']; LogProb = -56.93235542964953
# ==========
# 92. #endomondo
# MaxMatch = ['#', 'end', 'om', 'on', 'do']; LogProb = -47.98436812043095
# Reversed MaxMatch = ['#', 'en', 'do', 'mon', 'do']; LogProb = -52.82587161528012
# ==========
# 93. #wearesocial
# MaxMatch = ['#', 'weares', 'o', 'c', 'i', 'al']; LogProb = -64.13416198687925
# Reversed MaxMatch = ['#', 'we', 'are', 'social']; LogProb = -33.81338267207766
# ==========
# 94. #imsosore
# MaxMatch = ['#', 'i', 'ms', 'os', 'ore']; LogProb = -59.69339416354492
# Reversed MaxMatch = ['#', 'i', 'm', 'so', 'sore']; LogProb = -48.660167171313276
# ==========
# 95. #jordaan
# MaxMatch = ['#', 'jo', 'r', 'da', 'an']; LogProb = -53.42564526255384
# Reversed MaxMatch = ['#', 'j', 'or', 'da', 'an']; LogProb = -48.74470182509296
# ==========
# 96. #siberuang
# MaxMatch = ['#', 'sib', 'er', 'uang']; LogProb = -56.027851211461375
# Reversed MaxMatch = ['#', 'si', 'ber', 'uang']; LogProb = -55.334704030901435
# ==========
# 97. #longranger
# MaxMatch = ['#', 'long', 'ranger']; LogProb = -34.298210892128026
# Reversed MaxMatch = ['#', 'l', 'on', 'granger']; LogProb = -44.378525971611154
# ==========
# 98. #ritenow
# MaxMatch = ['#', 'rite', 'now']; LogProb = -32.64207188664795
# Reversed MaxMatch = ['#', 'rit', 'enow']; LogProb = -42.02088840859603
# ==========
# 99. #laundryservice
# MaxMatch = ['#', 'laundrys', 'er', 'vice']; LogProb = -52.290181593178005
# Reversed MaxMatch = ['#', 'laundry', 'service']; LogProb = -34.47338672578107
# ==========
# 100. #txlege
# MaxMatch = ['#', 't', 'x', 'leg', 'e']; LogProb = -55.11440695478732
# Reversed MaxMatch = ['#', 't', 'x', 'l', 'e', 'ge']; LogProb = -69.26708156883406
# ==========
# 101. #southampton
# MaxMatch = ['#', 'south', 'am', 'p', 'ton']; LogProb = -52.09488365569565
# Reversed MaxMatch = ['#', 's', 'out', 'ham', 'p', 'ton']; LogProb = -63.278947787283734
# ==========
# 102. #jrsurfboards
# MaxMatch = ['#', 'j', 'rs', 'urf', 'boards']; LogProb = -64.21770285436352
# Reversed MaxMatch = ['#', 'j', 'r', 'surfboards']; LogProb = -50.41837941627642
# ==========
# 103. #usydoweek
# MaxMatch = ['#', 'us', 'y', 'dow', 'e', 'e', 'k']; LogProb = -78.30630975614531
# Reversed MaxMatch = ['#', 'us', 'y', 'do', 'week']; LogProb = -48.888283764935146
# ==========
# 104. #uptonogood
# MaxMatch = ['#', 'up', 'ton', 'og', 'o', 'od']; LogProb = -70.56202155291402
# Reversed MaxMatch = ['#', 'up', 'to', 'no', 'good']; LogProb = -37.95611959084162
# ==========
# 105. #thewalkingdead
# MaxMatch = ['#', 'thew', 'alk', 'ing', 'dead']; LogProb = -64.8700280404032
# Reversed MaxMatch = ['#', 'the', 'walking', 'dead']; LogProb = -35.69988161129523
# ==========
# 106. #scifigeek
# MaxMatch = ['#', 's', 'c', 'if', 'i', 'geek']; LogProb = -59.85684318442116
# Reversed MaxMatch = ['#', 's', 'c', 'i', 'fi', 'geek']; LogProb = -67.55260117497592
# ==========
# 107. #wok
# MaxMatch = ['#', 'wo', 'k']; LogProb = -39.62299313579766
# Reversed MaxMatch = ['#', 'w', 'ok']; LogProb = -38.43736947013992
# ==========
# 108. #vscocam
# MaxMatch = ['#', 'vs', 'coca', 'm']; LogProb = -51.58519995497106
# Reversed MaxMatch = ['#', 'vs', 'c', 'o', 'cam']; LogProb = -59.63237101059509
# ==========
# 109. #foodporn
# MaxMatch = ['#', 'food', 'po', 'r', 'n']; LogProb = -57.01733126774336
# Reversed MaxMatch = ['#', 'food', 'p', 'or', 'n']; LogProb = -48.68572958898875
# ==========
# 110. #strictlyus
# MaxMatch = ['#', 'strictly', 'us']; LogProb = -31.978334807936903
# Reversed MaxMatch = ['#', 'strict', 'l', 'yus']; LogProb = -50.70973121761716
# ==========
# 111. #1yearofalmostisneverenough
# MaxMatch = ['#', '1', 'year', 'of', 'almost', 'is', 'never', 'enough']; LogProb = -60.88685623910921
# Reversed MaxMatch = ['#', '1', 'year', 'of', 'al', 'mos', 'tis', 'never', 'enough']; LogProb = -86.92774054397007
# ==========
# 112. #cdnpoli
# MaxMatch = ['#', 'c', 'd', 'n', 'pol', 'i']; LogProb = -63.09270811205109
# Reversed MaxMatch = ['#', 'c', 'd', 'n', 'po', 'li']; LogProb = -70.94922131304489
# ==========
# 113. #affsuzukicup
# MaxMatch = ['#', 'a', 'f', 'fs', 'u', 'z', 'u', 'k', 'i', 'cup']; LogProb = -104.56090380771312
# Reversed MaxMatch = ['#', 'a', 'f', 'f', 'suz', 'u', 'k', 'i', 'cup']; LogProb = -91.37383989104686
# ==========
# 114. #cornell
# MaxMatch = ['#', 'cornel', 'l']; LogProb = -39.18767506453982
# Reversed MaxMatch = ['#', 'cor', 'nell']; LogProb = -41.32774122803609
# ==========
# 115. #blackhat
# MaxMatch = ['#', 'black', 'hat']; LogProb = -32.65971714691727
# Reversed MaxMatch = ['#', 'b', 'lac', 'khat']; LogProb = -51.36441211734931
# ==========
# 116. #thenext5goldenyears
# MaxMatch = ['#', 'then', 'ex', 't', '5', 'golden', 'years']; LogProb = -69.78129654279155
# Reversed MaxMatch = ['#', 'the', 'next', '5', 'golden', 'years']; LogProb = -51.32548180278193
# ==========
# 117. #burgers
# MaxMatch = ['#', 'burg', 'ers']; LogProb = -42.02088840859603
# Reversed MaxMatch = ['#', 'bur', 'gers']; LogProb = -42.02088840859603
# ==========
# 118. #innoretail
# MaxMatch = ['#', 'inn', 'ore', 'tail']; LogProb = -50.506390293599125
# Reversed MaxMatch = ['#', 'in', 'no', 'retail']; LogProb = -35.34652286597065
# ==========
# 119. #nced
# MaxMatch = ['#', 'n', 'ce', 'd']; LogProb = -48.432463932607405
# Reversed MaxMatch = ['#', 'n', 'c', 'ed']; LogProb = -44.92121119098321
# ==========
# 120. #photoby
# MaxMatch = ['#', 'photo', 'by']; LogProb = -31.652346956540082
# Reversed MaxMatch = ['#', 'pho', 'toby']; LogProb = -42.02088840859603
# ==========
# 121. #thevoiceau
# MaxMatch = ['#', 'the', 'voice', 'a', 'u']; LogProb = -40.76322109722357
# Reversed MaxMatch = ['#', 'the', 'v', 'o', 'i', 'c', 'ea', 'u']; LogProb = -78.27907184983081
# ==========
# 122. #nevergetsold
# MaxMatch = ['#', 'never', 'gets', 'old']; LogProb = -38.77967393337103
# Reversed MaxMatch = ['#', 'never', 'get', 'sold']; LogProb = -38.98835789126076
# ==========
# 123. #insightmediasingapore
# MaxMatch = ['#', 'insight', 'media', 'sing', 'a', 'pore']; LogProb = -63.5615297924938
# Reversed MaxMatch = ['#', 'insight', 'me', 'di', 'as', 'inga', 'pore']; LogProb = -74.71486738172212
# ==========
# 124. #potd
# MaxMatch = ['#', 'pot', 'd']; LogProb = -34.72176694588523
# Reversed MaxMatch = ['#', 'po', 'td']; LogProb = -41.32774122803609

# %% [markdown]
# # Text Classification (4 marks)

# %% [markdown]
# ### Question 5 (1.0 mark)
#
# **Instructions**: Here we are interested to do text classification, to predict the country of origin of a given tweet. The task here is to create training, development and test partitions from the preprocessed data (`x_processed`) and convert the bag-of-words representation into feature vectors.
#
# **Task**: Create training, development and test partitions with a 70%/15%/15% ratio. Remember to preserve the ratio of the classes for all your partitions. That is, say we have only 2 classes and 70% of instances are labelled class A and 30% of instances are labelled class B, then the instances in training, development and test partitions should also preserve this 7:3 ratio. You may use sklearn's builtin functions for doing data partitioning.
#
# Next, turn the bag-of-words dictionary of each tweet into a feature vector. You may also use sklearn's builtin functions for doing this.
#
# You should produce 6 objects: `x_train`, `x_dev`, `x_test` which contain the input feature vectors, and `y_train`, `y_dev` and `y_test` which contain the labels.

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import StratifiedShuffleSplit

x_train, x_dev, x_test = None, None, None
y_train, y_dev, y_test = None, None, None

###
# Your answer BEGINS HERE
###

x_train, x_dev, x_test = [], [], []
y_train, y_dev, y_test = [], [], []

x_test_dev = []
y_test_dev = []

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=0)

for train_index, dev_index in sss.split(x_processed, y_processed):
    for index in train_index:
        x_train.append(x_processed[index])
        y_train.append(y_processed[index])
        
    for index in dev_index:
        x_test_dev.append(x_processed[index])
        y_test_dev.append(y_processed[index])
        
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=0)

for dev_index, test_index in sss.split(x_test_dev, y_test_dev):
    for index in test_index:
        x_test.append(x_test_dev[index])
        y_test.append(y_test_dev[index])
        
    for index in dev_index:
        x_dev.append(x_test_dev[index])
        y_dev.append(y_test_dev[index])

v = DictVectorizer(sparse=False)

v.fit(x_processed) 
x_test = v.transform(x_test)
x_dev = v.transform(x_dev)
x_train = v.transform(x_train)

###
# Your answer ENDS HERE
###

# %% [markdown]
# ### Question 6 (1.0 mark)
#
# **Instructions**: Now, let's build some classifiers. Here, we'll be comparing Naive Bayes and Logistic Regression. For each, you need to first find a good value for their main regularisation hyper-parameters, which you should identify using the scikit-learn docs or other resources. Use the development set you created for this tuning process; do **not** use cross-validation in the training set, or involve the test set in any way. You don't need to show all your work, but you do need to print out the **accuracy** with enough different settings to strongly suggest you have found an optimal or near-optimal choice. We should not need to look at your code to interpret the output.
#
# **Task**: Implement two text classifiers: Naive Bayes and Logistic Regression. Tune the hyper-parameters of these classifiers and print the task performance (accuracy) for different hyper-parameter settings.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

###
# Your answer BEGINS HERE
###

"""
The following hyperparameters have been arrived after acquiring knowledge from reading articles and
trailing different parameters for regularisation. 
""" 

print ("Naive Bayes Testing for Best Accuracy\n")
bestAccuracy = 0
bestAlpha = 1
for i in range(10, 0, -1):
    clf1 = MultinomialNB(alpha=(i/10))
    clf1.fit(x_train, y_train)
    y_dev_pred = clf1.predict(x_dev)
    print (f"For alpha={i/10}, accuracy is {round(accuracy_score(y_dev, y_dev_pred), 3)}")
    if bestAccuracy < accuracy_score(y_dev, y_dev_pred):
        bestAccuracy = accuracy_score(y_dev, y_dev_pred)
        bestAlpha = i/10
    
print ("\nBest Naive Bayes Model")
nb_model = MultinomialNB(alpha=bestAlpha)
nb_model.fit(x_train, y_train)
y_test_pred = nb_model.predict(x_test)
print(f"Accuracy: {round(accuracy_score(y_dev, y_dev_pred), 3)}")

print ("\nLogistic Regression testing for Best Accuracy")
for solver in ["newton-cg", "sag", "saga", "lbfgs"]:
    for regularization_strength in [0.01, 0.1, 1, 5, 10]: 
        clf2 = LogisticRegression(random_state=0, solver=solver, penalty="l2", C=regularization_strength)
        clf2.fit(x_train, y_train)
        y_dev_pred = clf2.predict(x_dev)
        print(f"For random_state=0, solver={solver} penalty=l2, C={regularization_strength}, Accuracy: {accuracy_score(y_dev, y_dev_pred)}")

print ("\nBest Logistic Regression Model")
clf2 = LogisticRegression(random_state=0, solver="lbfgs", penalty="l2", C=1.0)
clf2.fit(x_train, y_train)
y_test_pred = clf2.predict(x_test)
print(f"For random_state=0, solver={solver} penalty=l2, C={regularization_strength}, Accuracy: {accuracy_score(y_test, y_test_pred)}")
    
###
# Your answer ENDS HERE
###
# Out:
# Naive Bayes Testing for Best Accuracy
#
# For alpha=1.0, accuracy is 0.305
# For alpha=0.9, accuracy is 0.305
# For alpha=0.8, accuracy is 0.305
# For alpha=0.7, accuracy is 0.305
# For alpha=0.6, accuracy is 0.305
# For alpha=0.5, accuracy is 0.305
# For alpha=0.4, accuracy is 0.305
# For alpha=0.3, accuracy is 0.291
# For alpha=0.2, accuracy is 0.277
# For alpha=0.1, accuracy is 0.255
#
# Best Naive Bayes Model
# Accuracy: 0.255
#
# Logistic Regression testing for Best Accuracy
# For random_state=0, solver=newton-cg penalty=l2, C=0.01, Accuracy: 0.2553191489361702
# For random_state=0, solver=newton-cg penalty=l2, C=0.1, Accuracy: 0.2765957446808511
# For random_state=0, solver=newton-cg penalty=l2, C=1, Accuracy: 0.2978723404255319
# For random_state=0, solver=newton-cg penalty=l2, C=5, Accuracy: 0.28368794326241137
# For random_state=0, solver=newton-cg penalty=l2, C=10, Accuracy: 0.2907801418439716
# For random_state=0, solver=sag penalty=l2, C=0.01, Accuracy: 0.2553191489361702
# For random_state=0, solver=sag penalty=l2, C=0.1, Accuracy: 0.2765957446808511
# For random_state=0, solver=sag penalty=l2, C=1, Accuracy: 0.2978723404255319
# c:\users\sharo\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# For random_state=0, solver=sag penalty=l2, C=5, Accuracy: 0.28368794326241137
# c:\users\sharo\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# For random_state=0, solver=sag penalty=l2, C=10, Accuracy: 0.2978723404255319
# For random_state=0, solver=saga penalty=l2, C=0.01, Accuracy: 0.2553191489361702
# For random_state=0, solver=saga penalty=l2, C=0.1, Accuracy: 0.2765957446808511
# For random_state=0, solver=saga penalty=l2, C=1, Accuracy: 0.2978723404255319
# c:\users\sharo\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# For random_state=0, solver=saga penalty=l2, C=5, Accuracy: 0.2907801418439716
# c:\users\sharo\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# For random_state=0, solver=saga penalty=l2, C=10, Accuracy: 0.2907801418439716
# For random_state=0, solver=lbfgs penalty=l2, C=0.01, Accuracy: 0.2553191489361702
# For random_state=0, solver=lbfgs penalty=l2, C=0.1, Accuracy: 0.2765957446808511
# For random_state=0, solver=lbfgs penalty=l2, C=1, Accuracy: 0.2978723404255319
# For random_state=0, solver=lbfgs penalty=l2, C=5, Accuracy: 0.28368794326241137
# For random_state=0, solver=lbfgs penalty=l2, C=10, Accuracy: 0.2907801418439716
#
# Best Logistic Regression Model
# Accuracy: 0.28169014084507044

# %% [markdown]
# ### Question 7 (1.0 mark)
#
# **Instructions**: Using the best settings you have found, compare the two classifiers based on performance in the test set. Print out both **accuracy** and **macro-averaged F-score** for each classifier. Be sure to label your output. You may use sklearn's inbuilt functions.
#
# **Task**: Compute test performance in terms of accuracy and macro-averaged F-score for both Naive Bayes and Logistic Regression, using their optimal hyper-parameter settings based on their development performance.

# %%
###
# Your answer BEGINS HERE
###

from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score


print ("Naive Bayes")
nb_model = MultinomialNB(alpha=bestAlpha)
nb_model.fit(x_train, y_train)
y_test_pred = nb_model.predict(x_test)
print(f"F-Score: {f1_score(y_test, y_test_pred, average='macro')}")
print(f"Accuracy: {accuracy_score(y_test, y_test_pred)}")

print("=======")

print ("Logistic Regression")
clf2 = LogisticRegression(random_state=0)
clf2.fit(x_train, y_train)
y_test_pred = clf2.predict(x_test)
print(f"F-Score: {f1_score(y_test, y_test_pred, average='macro')}")
print(f"Accuracy: {accuracy_score(y_test, y_test_pred)}")


###
# Your answer ENDS HERE
###
# Out:
# Naive Bayes
# F-Score: 0.2919685491853684
# Accuracy: 0.29577464788732394
# =======
# Logistic Regression
# F-Score: 0.2737420554428668
# Accuracy: 0.28169014084507044

# %% [markdown]
# ### Question 8 (1.0 mark)
#
# **Instructions**: Print the most important features and their weights for each class for the two classifiers.
#
#
# **Task**: For each of the classifiers (Logistic Regression and Naive Bayes) you've built in the previous question, print out the top-20 features (words) with the highest weight for each class (countries).
#
# An example output:
# ```
# Classifier = Logistic Regression
#
# Country = au
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Country = ca
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Classifier = Naive Bayes
#
# Country = au
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
#
# Country = ca
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
# ```
#
# Have a look at the output, and see if you notice any trend/pattern in the words for each country.

# %%
###
# Your answer BEGINS HERE
###

print ("Classifier = Naive Bayes")
for class_index in range(len(nb_model.feature_log_prob_)):    
    print (f"\nCountry = {nb_model.classes_[class_index]}")
    features_scores = ""
    for item in sorted(zip(nb_model.feature_log_prob_[class_index], v.get_feature_names()), key=lambda el: el[0], reverse=True)[:20]:
        features_scores += f"{item[1]} ({round(item[0], 3)}) "
    print (features_scores.strip())
     
print ("\n===========")
        
print ("\nClassifier = Logistic Regression")
for class_index in range(len(nb_model.coef_)):    
    print (f"\nCountry = {nb_model.classes_[class_index]}")
    features_scores = ""
    
    for item in sorted(zip(clf2.coef_[class_index], v.get_feature_names()), key=lambda el: el[0], reverse=True)[:20]:
        features_scores += f"{item[1]} ({round(item[0], 3)}) "
    print (features_scores.strip())

###
# Your answer ENDS HERE
###
# Out:
# Classifier = Naive Bayes
#
# Country = au
# great (-6.715) i'm (-6.715) melbourne (-6.715) love (-6.897) one (-6.897) keep (-7.12) little (-7.12) make (-7.12) #affsuzukicup (-7.408) #melbourne (-7.408) #mtvhottest (-7.408) #sunrise (-7.408) already (-7.408) another (-7.408) anything (-7.408) australia (-7.408) australian (-7.408) away (-7.408) beach (-7.408) best (-7.408)
#
# Country = ca
# i'm (-6.562) got (-6.716) thing (-6.716) first (-6.899) get (-6.899) great (-6.899) right (-6.899) bed (-7.122) life (-7.122) one (-7.122) school (-7.122) u (-7.122) #devacurl (-7.409) #photo (-7.409) @mt_dougrams (-7.409) awesome (-7.409) bc (-7.409) bus (-7.409) class (-7.409) data (-7.409)
#
# Country = de
# love (-7.062) night (-7.062) photo (-7.062) posted (-7.062) #mkmedi (-7.35) #rosegold (-7.35) almost (-7.35) bad (-7.35) bild (-7.35) day (-7.35) des (-7.35) done (-7.35) enough (-7.35) factory (-7.35) germany (-7.35) good (-7.35) https://t.co/dpfrjtdarl (-7.35) markus (-7.35) medinger (-7.35) never (-7.35)
#
# Country = gb
# x (-6.556) got (-6.71) i'm (-6.71) sure (-6.71) beat (-6.892) hope (-6.892) i've (-6.892) new (-6.892) well (-6.892) back (-7.115) fear (-7.115) get (-7.115) plz (-7.115) right (-7.115) #ff (-7.403) @skyhelpteam (-7.403) always (-7.403) beautiful (-7.403) close (-7.403) day (-7.403)
#
# Country = id
# pic (-6.087) i'm (-6.875) rt (-6.875) wkwk (-6.875) cafe (-7.099) coffee (-7.099) donuts (-7.099) hiks (-7.099) others (-7.099) @jcoindonesia (-7.386) banget (-7.386) direction (-7.386) flat (-7.386) ga (-7.386) gulung (-7.386) haha (-7.386) hari (-7.386) hehhe (-7.386) house (-7.386) ini (-7.386)
#
# Country = my
# i'm (-5.659) selangor (-6.547) happy (-6.701) w (-6.701) birthday (-6.883) jaya (-6.883) thank (-6.883) cendol (-7.106) hahaha (-7.106) johor (-7.106) kuala (-7.106) lumpur (-7.106) maybe (-7.106) ni (-7.106) one (-7.106) subang (-7.106) take (-7.106) @poemporns (-7.394) abg (-7.394) ak (-7.394)
#
# Country = ph
# follow (-6.186) please (-6.41) make (-6.697) #hometomama (-6.88) @iam3l (-6.88) @justinbieber (-6.88) back (-6.88) city (-6.88) come (-6.88) dreams (-6.88) good (-6.88) im (-6.88) like (-6.88) true (-6.88) evening (-7.103) gonna (-7.103) ko (-7.103) manila (-7.103) mo (-7.103) us (-7.103)
#
# Country = sg
# singapore (-6.284) i'm (-6.535) others (-6.689) park (-6.871) w (-6.871) pic (-7.094) say (-7.094) work (-7.094) @f41bad80f87243a (-7.382) @khoirul_irwanqu (-7.382) @ukhtirofie_ (-7.382) @weichen_7 (-7.382) @wwindaruby (-7.382) @zherenne (-7.382) air (-7.382) another (-7.382) bangkalan (-7.382) cari (-7.382) far (-7.382) fitness (-7.382)
#
# Country = us
# i'm (-6.546) like (-6.546) u (-6.546) get (-6.701) happy (-6.883) love (-6.883) tonight (-6.883) boy (-7.106) day (-7.106) ever (-7.106) go (-7.106) home (-7.106) hopefully (-7.106) house (-7.106) i'll (-7.106) much (-7.106) new (-7.106) really (-7.106) true (-7.106) @tushposhboss (-7.394)
#
# Country = za
# u (-6.556) day (-6.711) happy (-6.711) everything (-6.893) god (-6.893) good (-6.893) love (-6.893) africa (-7.116) b (-7.116) better (-7.116) de (-7.116) life (-7.116) man (-7.116) next (-7.116) something (-7.116) south (-7.116) thank (-7.116) that's (-7.116) time (-7.116) ur (-7.116)
#
# ===========
#
# Classifier = Logistic Regression
#
# Country = au
# melbourne (0.966) #melbourne (0.913) little (0.839) brilliant (0.799) australian (0.706) green (0.704) hey (0.695) great (0.677) literally (0.666) australia (0.661) #sunrise (0.66) away (0.631) beach (0.586) visit (0.57) @christorrano (0.567) http://t.co/blhj9cmxit (0.567) #amazing (0.564) #jed (0.564) @mattjohnbond (0.564) @micksunnyg (0.564)
#
# Country = ca
# thing (1.359) bed (0.999) got (0.92) happen (0.908) hate (0.855) right (0.792) @aliclarke (0.689) sounds (0.685) works (0.681) healthy (0.63) @lola9793 (0.615) life (0.613) first (0.601) awesome (0.597) joking (0.59) mood (0.566) data (0.561) @mtldrivefor25 (0.55) agrees (0.55) thomas (0.55)
#
# Country = de
# germany (0.801) https://t.co/df7ficsci3 (0.788) roseninsel (0.788) done (0.784) night (0.784) @fabiomarabini (0.777) happened (0.746) bad (0.68) #truegrip (0.669) gauting (0.669) https://t.co/brkwmsvzrb (0.669) enough (0.654) photo (0.649) posted (0.649) factory (0.644) adlib (0.607) https://t.co/psveyka5g3 (0.607) #asksteven (0.602) @stevenfhoney (0.602) facetime (0.602)
#
# Country = gb
# x (1.395) well (1.036) sure (0.92) plz (0.833) got (0.713) golf (0.71) holly (0.706) always (0.684) i've (0.668) http://t.co/w0tjrah9y7 (0.666) interesting (0.666) prom (0.666) this'll (0.666) #ff (0.657) wbu (0.647) stressed (0.646) @skyhelpteam (0.636) many (0.611) new (0.608) http://t.co/giq4dl9jcq (0.595)
#
# Country = id
# pic (1.576) wkwk (0.952) selamat (0.812) cafe (0.792) http://t.co/0uccot9gdn (0.737) karaoke (0.707) world (0.684) donuts (0.66) https://t.co/exshmyqmsl (0.654) https://t.co/xxbmsbuf0r (0.641) coffee (0.631) @smandatas_261 (0.631) http://t.co/wyldhnlap4 (0.631) https://t.co/3sxyzl4crq (0.631) pranciska (0.631) ini (0.596) flat (0.584) night (0.573) https://t.co/cxzfcg0hyi (0.554) change (0.551)
#
# Country = my
# thank (1.136) @poemporns (1.126) i'm (0.984) selangor (0.951) johor (0.872) ni (0.749) @juztakumi (0.73) badminton (0.701) hahaha (0.677) congrats (0.669) care (0.667) lagi (0.651) news (0.637) kuala (0.629) lumpur (0.629) @markthewise (0.622) depressing (0.622) @12_maiii (0.622) promise (0.611) @nabil_bil_bil (0.591)
#
# Country = ph
# follow (0.919) manila (0.865) @home (0.861) @qweeesha (0.849) ko (0.842) city (0.761) evening (0.722) space (0.722) reason (0.713) back (0.702) mcdonald's (0.691) us (0.691) @fuccyoudis2o9 (0.656) baby (0.652) #sorrynotsorry (0.649) @veronicavispo (0.649) bath (0.648) sight (0.632) thankyou (0.612) gonna (0.607)
#
# Country = sg
# singapore (1.725) others (0.935) hang (0.748) food (0.716) perfect (0.711) side (0.686) https://t.co/potgoiy5rv (0.683) park (0.68) watching (0.671) hotel (0.668) fitness (0.658) @dolly07397340 (0.657) @moonbowcloth_id (0.657) @sbuxindonesia (0.657) https://t.co/bwenaysyrq (0.657) https://t.co/g0022mcf4u (0.657) yepz (0.657) keri (0.644) @weichen_7 (0.622) use (0.619)
#
# Country = us
# tonight (0.921) like (0.838) get (0.781) u (0.758) hopefully (0.755) ever (0.716) much (0.7) sick (0.681) home (0.68) i'll (0.679) freakin (0.679) gym (0.671) @ansleytolbert (0.661) @savannerdd (0.661) boy (0.656) happy (0.654) true (0.628) http://t.co/ykkwnmzsir (0.625) @b_diddddy (0.623) ahhahaha (0.623)
#
# Country = za
# man (0.935) god (0.861) u (0.82) that's (0.759) de (0.745) africa (0.739) south (0.739) close (0.738) weekend (0.724) day (0.714) @zimtweets (0.652) akubabuze (0.652) something (0.643) feel (0.641) life (0.64) makes (0.634) everything (0.619) drawing (0.616) making (0.614) @ferlo_mabkay (0.612)

# %% [markdown]
# ## Helper Functions

# %%
def checkDist(title, labels):
    labels = sorted(labels)
    print (f"Distribution of {title}")
    print (f"No of items: {len(labels)}")
    for item in set(labels):
        print (f"{item}: {round((labels.count(item)/len(labels))*100, 2)}%")
    print ("========")
        

checkDist ("y_processed", y_processed)
checkDist ("y_train", y_train)
checkDist ("y_dev", y_dev)
checkDist ("y_test", y_test)
# Out:
# Distribution of y_processed
# No of items: 943
# sg: 9.86%
# au: 10.6%
# my: 10.6%
# gb: 10.6%
# us: 10.6%
# de: 5.3%
# ph: 10.6%
# ca: 10.6%
# id: 10.6%
# za: 10.6%
# ========
# Distribution of y_train
# No of items: 660
# sg: 9.85%
# au: 10.61%
# my: 10.61%
# gb: 10.61%
# us: 10.61%
# de: 5.3%
# ph: 10.61%
# ca: 10.61%
# id: 10.61%
# za: 10.61%
# ========
# Distribution of y_dev
# No of items: 141
# sg: 9.93%
# au: 10.64%
# my: 10.64%
# gb: 10.64%
# us: 10.64%
# de: 4.96%
# ph: 10.64%
# ca: 10.64%
# id: 10.64%
# za: 10.64%
# ========
# Distribution of y_test
# No of items: 142
# sg: 9.86%
# au: 10.56%
# my: 10.56%
# gb: 10.56%
# us: 10.56%
# de: 5.63%
# ph: 10.56%
# ca: 10.56%
# id: 10.56%
# za: 10.56%
# ========
